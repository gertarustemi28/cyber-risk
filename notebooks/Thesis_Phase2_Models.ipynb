# %% [markdown]
# # A Data-Driven Cyber Risk Analytics and Decision Support Framework
# ## for Digital Banking Environments
# **Gerta Rustemi | Student ID: 070124011 | MSc Computer Science, UNYT**
#
# ---
#
# # PHASE 2 — Model Training, Evaluation & Risk Framework
#
# **Prerequisites:** Phase 1 notebook must be completed first.
# All inputs are loaded from `My Drive/Thesis/preprocessed/`
#
# This notebook covers:
# 1. Environment setup and loading Phase 1 outputs
# 2. **Model 1 — Random Forest** (bagging ensemble)
# 3. **Model 2 — XGBoost** (gradient boosting)
# 4. **Model 3 — LSTM** (recurrent neural network for sequential patterns)
# 5. **Model 4 — Isolation Forest** (unsupervised anomaly detection)
# 6. Comparative evaluation across all models
# 7. SHAP explainability analysis (Random Forest + XGBoost)
# 8. Risk Tier Decision-Support Framework (Critical / High / Medium / Low)
# 9. Final summary and dissertation outputs
#
# **Dataset:** CICIDS2017 | **Training set:** 5,836,260 records (post-SMOTE) | **Test set:** 195,180 records
# **Classes:** 10 (BENIGN + 9 attack categories)

# %% [markdown]
# ---
# ## CELL 1 — Install Libraries
# > Run this first and restart runtime if prompted.

# %%
# !pip install xgboost shap imbalanced-learn --quiet

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import joblib
import os
import time
import gc
import warnings
warnings.filterwarnings('ignore')

# Sklearn
from sklearn.ensemble import RandomForestClassifier, IsolationForest
from sklearn.metrics import (
    classification_report, confusion_matrix,
    f1_score, precision_score, recall_score,
    roc_auc_score, average_precision_score,
    roc_curve, precision_recall_curve
)
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.preprocessing import label_binarize

# XGBoost
import xgboost as xgb

# TensorFlow / Keras — DEFERRED: imported later, immediately before the
# LSTM section (CELL 10), to avoid TensorFlow's GPU-context RAM overhead
# during Random Forest / XGBoost / Isolation Forest training.

# SHAP
import shap

# Style
plt.style.use('seaborn-v0_8-whitegrid')
TEAL      = '#0ABAB5'
DARK_TEAL = '#088A87'
N_CLASSES = 10

print(f' All libraries imported (TensorFlow import deferred until the LSTM section)')
print(f'XGBoost: {xgb.__version__}')
# Out:
#  All libraries imported (TensorFlow import deferred until the LSTM section)
# XGBoost: 3.4.1

# %% [markdown]
# ---
# ## CELL 2 — Mount Drive and Load Phase 1 Outputs

# %%
from google.colab import drive
drive.mount('/content/drive')

# ---- UPDATE if your path differs ----
PREP_DIR  = '/content/drive/MyDrive/Thesis/preprocessed/'
MODEL_DIR = '/content/drive/MyDrive/Thesis/models/'
FIG_DIR   = '/content/drive/MyDrive/Thesis/figures/'
# -------------------------------------

os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(FIG_DIR,   exist_ok=True)

print('Loading Phase 1 outputs...')

# Features and labels
X_train_sm  = np.load(f'{PREP_DIR}X_train_sm.npy')   # (5836260, 78) SMOTE-balanced
y_train_sm  = np.load(f'{PREP_DIR}y_train_sm.npy')   # (5836260,)
X_test      = np.load(f'{PREP_DIR}X_test.npy')        # (195180, 78)
y_test      = np.load(f'{PREP_DIR}y_test.npy')        # (195180,)
X_train_pca = np.load(f'{PREP_DIR}X_train_pca.npy')  # (5836260, 16) PCA-reduced
X_test_pca  = np.load(f'{PREP_DIR}X_test_pca.npy')   # (195180, 16)

# Fitted objects
le               = joblib.load(f'{PREP_DIR}label_encoder.pkl')
scaler           = joblib.load(f'{PREP_DIR}scaler.pkl')
pca              = joblib.load(f'{PREP_DIR}pca.pkl')
selected_features = joblib.load(f'{PREP_DIR}selected_features.pkl')
feature_names    = pd.read_csv(f'{PREP_DIR}feature_names.csv').iloc[:, 0].tolist()

CLASS_NAMES = list(le.classes_)  # 10 class names

print(f'All Phase 1 outputs loaded')
print(f'Training set (SMOTE): {X_train_sm.shape[0]:,} rows × {X_train_sm.shape[1]} features')
print(f'Test set:             {X_test.shape[0]:,} rows × {X_test.shape[1]} features')
print(f'PCA training set:     {X_train_pca.shape[0]:,} rows × {X_train_pca.shape[1]} components')
print(f'Classes: {CLASS_NAMES}')
# Out:
# Mounted at /content/drive
# Loading Phase 1 outputs...
# All Phase 1 outputs loaded
# Training set (SMOTE): 5,836,260 rows × 78 features
# Test set:             195,180 rows × 78 features
# PCA training set:     5,836,260 rows × 16 components
# Classes: ['BENIGN', 'DDoS', 'DoS Hulk', 'DoS Slowhttptest', 'DoS Slowloris', 'FTP-Patator', 'SSH-Patator', 'Web Attack - Brute Force', 'Web Attack - SQL Injection', 'Web Attack - XSS']

# %% [markdown]
# ---
# ## CELL 2a — Reduce Memory Footprint (float32 cast)
# Casts the large feature arrays from float64 to float32 (halves their RAM
# footprint) and frees the now-unreferenced float64 copies, to leave enough
# headroom for Random Forest / XGBoost / LSTM training on this Colab instance.

# %%
# ── Reduce memory footprint: float64 → float32, then free unused memory ────
X_train_sm  = X_train_sm.astype('float32')
X_test      = X_test.astype('float32')
X_train_pca = X_train_pca.astype('float32')
X_test_pca  = X_test_pca.astype('float32')

gc.collect()

import psutil
mem = psutil.virtual_memory()
print('Converted feature arrays to float32:')
print(f'  X_train_sm:  {X_train_sm.nbytes / 1e9:.2f} GB')
print(f'  X_test:      {X_test.nbytes / 1e9:.2f} GB')
print(f'  X_train_pca: {X_train_pca.nbytes / 1e9:.2f} GB')
print(f'  X_test_pca:  {X_test_pca.nbytes / 1e9:.2f} GB')
print(f'\nRAM check — Total: {mem.total/1e9:.2f} GB | Available: {mem.available/1e9:.2f} GB | Used: {mem.used/1e9:.2f} GB ({mem.percent}%)')
# Out:
# Converted feature arrays to float32:
#   X_train_sm:  1.82 GB
#   X_test:      0.06 GB
#   X_train_pca: 0.37 GB
#   X_test_pca:  0.01 GB
#
# RAM check — Total: 13.61 GB | Available: 9.69 GB | Used: 3.58 GB (28.8%)

# %% [markdown]
# ---
# ## CELL 2b — Carve Validation Split (leakage fix)
# Splits 10% out of the SMOTE-balanced training partition to serve as a genuine
# validation set for XGBoost's `eval_set` and the LSTM's early stopping /
# checkpointing / LR reduction, so the test partition is never touched during
# training.

# %%
# ── Carve a genuine validation split out of the training partition ─────────
# XGBoost's eval_set and the LSTM's validation_data/EarlyStopping/
# ModelCheckpoint/ReduceLROnPlateau must never see the test set during
# training. This carves 10% out of the SMOTE-balanced training partition
# for that purpose; the test set (X_test/y_test) remains fully untouched
# until final evaluation.
from sklearn.model_selection import train_test_split

train_final_idx, val_idx = train_test_split(
    np.arange(X_train_sm.shape[0]),
    test_size=0.1,
    random_state=42,
    stratify=y_train_sm
)

X_train_final = X_train_sm[train_final_idx]
y_train_final = y_train_sm[train_final_idx]
X_val         = X_train_sm[val_idx]
y_val         = y_train_sm[val_idx]

X_train_pca_final = X_train_pca[train_final_idx]
X_val_pca         = X_train_pca[val_idx]

print('Validation split carved from the training partition:')
print(f'  Training (final): {X_train_final.shape[0]:,} rows')
print(f'  Validation:       {X_val.shape[0]:,} rows')
print(f'  Test (untouched): {X_test.shape[0]:,} rows')
# Out:
# Validation split carved from the training partition:
#   Training (final): 5,252,634 rows
#   Validation:       583,626 rows
#   Test (untouched): 195,180 rows

# %% [markdown]
# ---
# ## CELL 3 — Helper Functions
# Shared evaluation and plotting utilities used by all four models.

# %%
# ── Evaluation helper ──────────────────────────────────────────────────────
def evaluate_model(name, y_true, y_pred, y_prob=None, training_time=None):
    """Compute and print all dissertation evaluation metrics."""
    results = {
        'model': name,
        'macro_f1':    f1_score(y_true, y_pred, average='macro',    zero_division=0),
        'weighted_f1': f1_score(y_true, y_pred, average='weighted', zero_division=0),
        'macro_precision': precision_score(y_true, y_pred, average='macro',    zero_division=0),
        'macro_recall':    recall_score(y_true, y_pred, average='macro',       zero_division=0),
        'fpr': None,
        'auc_roc': None,
        'training_time_s': training_time
    }

    # False Positive Rate (macro average)
    cm = confusion_matrix(y_true, y_pred)
    fpr_per_class = []
    for i in range(len(cm)):
        fp = cm[:, i].sum() - cm[i, i]
        tn = cm.sum() - cm[i, :].sum() - cm[:, i].sum() + cm[i, i]
        fpr_per_class.append(fp / (fp + tn) if (fp + tn) > 0 else 0)
    results['fpr'] = np.mean(fpr_per_class)

    # AUC-ROC (requires probability scores)
    if y_prob is not None:
        try:
            results['auc_roc'] = roc_auc_score(
                label_binarize(y_true, classes=list(range(N_CLASSES))),
                y_prob, average='macro', multi_class='ovr'
            )
        except Exception:
            results['auc_roc'] = None

    print(f'\n{"="*55}')
    print(f'  {name} — Evaluation Results')
    print(f'{"="*55}')
    print(f'  Macro F1-score:      {results["macro_f1"]:.4f}')
    print(f'  Weighted F1-score:   {results["weighted_f1"]:.4f}')
    print(f'  Macro Precision:     {results["macro_precision"]:.4f}')
    print(f'  Macro Recall:        {results["macro_recall"]:.4f}')
    print(f'  Mean FPR:            {results["fpr"]:.4f}')
    if results['auc_roc']:
        print(f'  AUC-ROC (macro):     {results["auc_roc"]:.4f}')
    if training_time:
        print(f'  Training time:       {training_time:.1f}s')
    print(f'\n  Per-class report:')
    print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, zero_division=0))
    return results


# ── Confusion matrix plot ──────────────────────────────────────────────────
def plot_confusion_matrix(name, y_true, y_pred, filename):
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    fig, axes = plt.subplots(1, 2, figsize=(20, 8))
    for ax, data, title, fmt in zip(
        axes,
        [cm, cm_norm],
        ['Counts', 'Normalised (row %)'],
        ['d', '.2f']
    ):
        sns.heatmap(
            data, annot=True, fmt=fmt, cmap='YlOrRd',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
            linewidths=0.4, ax=ax, cbar=True
        )
        ax.set_title(f'{name} — Confusion Matrix ({title})', fontsize=12, fontweight='bold')
        ax.set_ylabel('True Label', fontsize=11)
        ax.set_xlabel('Predicted Label', fontsize=11)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=9)
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=9)

    plt.tight_layout()
    plt.savefig(f'{FIG_DIR}{filename}', dpi=150, bbox_inches='tight')
    plt.show()
    print(f'Saved: {filename}')


# ── Precision-Recall curve ─────────────────────────────────────────────────
def plot_pr_curves(name, y_true, y_prob, filename):
    y_bin = label_binarize(y_true, classes=list(range(N_CLASSES)))
    fig, ax = plt.subplots(figsize=(10, 7))
    cmap = plt.cm.get_cmap('tab10', N_CLASSES)
    for i in range(N_CLASSES):
        prec, rec, _ = precision_recall_curve(y_bin[:, i], y_prob[:, i])
        ap = average_precision_score(y_bin[:, i], y_prob[:, i])
        ax.plot(rec, prec, color=cmap(i), lw=1.5,
                label=f'{CLASS_NAMES[i]} (AP={ap:.2f})')
    ax.set_xlabel('Recall', fontsize=12)
    ax.set_ylabel('Precision', fontsize=12)
    ax.set_title(f'{name} — Precision-Recall Curves (per class)', fontsize=13, fontweight='bold')
    ax.legend(fontsize=8, bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.tight_layout()
    plt.savefig(f'{FIG_DIR}{filename}', dpi=150, bbox_inches='tight')
    plt.show()


# Storage for comparative table
all_results = []
print(' Helper functions defined')
# Out:
#  Helper functions defined

# %% [markdown]
# ---
# # MODEL 1 — RANDOM FOREST
#
# A bagging ensemble of decision trees offering robustness against overfitting
# and interpretable feature importance scoring (Géron, 2020).
# Trained on full 78 features (SMOTE-balanced).
#
# > ⏱ **Expected training time:** 15–30 minutes on T4 GPU (CPU-based, uses all cores)

# %% [markdown]
# ## CELL 4 — Train Random Forest

# %%
print('Training Random Forest...')
print(f'Training set: {X_train_sm.shape[0]:,} rows × {X_train_sm.shape[1]} features')
print('This may take 15-30 minutes. Do not close the tab.\n')

t0 = time.time()

rf = RandomForestClassifier(
    n_estimators=50,
    max_depth=15,
    min_samples_leaf=100,
    max_features='sqrt',
    max_samples=0.2,
    class_weight='balanced',
    random_state=42,
    n_jobs=2,
    verbose=1
)

rf.fit(X_train_sm, y_train_sm)
rf_time = time.time() - t0

print(f'\n Random Forest trained in {rf_time:.1f}s ({rf_time/60:.1f} min)')
joblib.dump(rf, f'{MODEL_DIR}random_forest.pkl')
print(' Model saved to Drive')
# Out:
# Training Random Forest...
# Training set: 5,836,260 rows × 78 features
# This may take 15-30 minutes. Do not close the tab.
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:  3.7min finished
#  Random Forest trained in 224.9s (3.7 min)
#  Model saved to Drive

# %% [markdown]
# ## CELL 5 — Evaluate Random Forest

# %%
y_pred_rf   = rf.predict(X_test)
y_prob_rf   = rf.predict_proba(X_test)

rf_results = evaluate_model('Random Forest', y_test, y_pred_rf, y_prob_rf, rf_time)
all_results.append(rf_results)

plot_confusion_matrix('Random Forest', y_test, y_pred_rf, 'cm_random_forest.png')
plot_pr_curves('Random Forest', y_test, y_prob_rf, 'pr_random_forest.png')
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.8s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:    0.8s finished
# =======================================================
#   Random Forest — Evaluation Results
# =======================================================
#   Macro F1-score:      0.7792
#   Weighted F1-score:   0.9949
#   Macro Precision:     0.7482
#   Macro Recall:        0.8967
#   Mean FPR:            0.0008
#   AUC-ROC (macro):     0.9997
#   Training time:       224.9s
#
#   Per-class report:
#                             precision    recall  f1-score   support
#
#                     BENIGN       1.00      0.99      1.00    145907
#                       DDoS       1.00      1.00      1.00     25603
#                   DoS Hulk       1.00      1.00      1.00     19289
#           DoS Slowhttptest       0.93      0.99      0.96      1046
#              DoS Slowloris       0.99      0.99      0.99      1077
#                FTP-Patator       0.99      1.00      0.99      1186
#                SSH-Patator       0.94      1.00      0.96       644
#   Web Attack - Brute Force       0.36      0.49      0.42       294
# Web Attack - SQL Injection       0.17      0.75      0.27         4
#           Web Attack - XSS       0.12      0.75      0.20       130
#
#                   accuracy                           0.99    195180
#                  macro avg       0.75      0.90      0.78    195180
#               weighted avg       1.00      0.99      0.99    195180
# Saved: cm_random_forest.png

# %% [markdown]
# ## CELL 6 — Random Forest Feature Importance

# %%
importances = pd.Series(rf.feature_importances_, index=feature_names).sort_values(ascending=True)
top20 = importances.nlargest(20).sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(10, 8))
bars = ax.barh(top20.index, top20.values, color=TEAL, edgecolor='white')
ax.set_xlabel('Feature Importance (Gini Impurity Reduction)', fontsize=12)
ax.set_title('Random Forest — Top 20 Feature Importances', fontsize=13, fontweight='bold')
for bar, val in zip(bars, top20.values):
    ax.text(bar.get_width() + 0.0005, bar.get_y() + bar.get_height()/2,
            f'{val:.4f}', va='center', fontsize=8)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}rf_feature_importance.png', dpi=150, bbox_inches='tight')
plt.show()
print(' Feature importance plot saved')
# Out:
#  Feature importance plot saved

# %%
# Free memory from Random Forest evaluation artefacts before XGBoost
gc.collect()
print('Memory freed before XGBoost training.')
# Out:
# Memory freed before XGBoost training.

# %% [markdown]
# ---
# # MODEL 2 — XGBOOST
#
# A sequential gradient boosting algorithm with state-of-the-art performance
# on structured tabular data and native SHAP compatibility (Kumar & Singh, 2023).
# Trained on full 78 features (SMOTE-balanced).
#
# > ⏱ **Expected training time:** 20–40 minutes on T4 GPU

# %% [markdown]
# ## CELL 7 — Train XGBoost

# %%
print('Training XGBoost...')
print(f'Training set: {X_train_final.shape[0]:,} rows × {X_train_final.shape[1]} features')
print('This may take 20-40 minutes. Do not close the tab.\n')

t0 = time.time()

xgb_model = xgb.XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_weight=3,
    gamma=0.1,
    reg_alpha=0.1,
    reg_lambda=1.0,
    objective='multi:softprob',
    num_class=N_CLASSES,
    eval_metric='mlogloss',
    use_label_encoder=False,
    tree_method='hist',
    device='cuda',
    random_state=42,
    n_jobs=-1,
    verbosity=1
)

xgb_model.fit(
    X_train_final, y_train_final,
    eval_set=[(X_val, y_val)],
    verbose=50
)
xgb_time = time.time() - t0

print(f'\n  XGBoost trained in {xgb_time:.1f}s ({xgb_time/60:.1f} min)')
xgb_model.save_model(f'{MODEL_DIR}xgboost_model.json')
print('  Model saved to Drive')
# Out:
# Training XGBoost...
# Training set: 5,252,634 rows × 78 features
# This may take 20-40 minutes. Do not close the tab.
#
# [0]	validation_0-mlogloss:1.87541
# [50]	validation_0-mlogloss:0.12410
# [100]	validation_0-mlogloss:0.09413
# [150]	validation_0-mlogloss:0.07943
# [200]	validation_0-mlogloss:0.07072
# [250]	validation_0-mlogloss:0.06384
# [299]	validation_0-mlogloss:0.05879
#
#   XGBoost trained in 291.4s (4.9 min)
#   Model saved to Drive

# %% [markdown]
# ## CELL 8 — Evaluate XGBoost

# %%
y_pred_xgb = xgb_model.predict(X_test)
y_prob_xgb = xgb_model.predict_proba(X_test)

xgb_results = evaluate_model('XGBoost', y_test, y_pred_xgb, y_prob_xgb, xgb_time)
all_results.append(xgb_results)

plot_confusion_matrix('XGBoost', y_test, y_pred_xgb, 'cm_xgboost.png')
plot_pr_curves('XGBoost', y_test, y_prob_xgb, 'pr_xgboost.png')
# Out:
# =======================================================
#   XGBoost — Evaluation Results
# =======================================================
#   Macro F1-score:      0.9024
#   Weighted F1-score:   0.9990
#   Macro Precision:     0.9151
#   Macro Recall:        0.8943
#   Mean FPR:            0.0001
#   AUC-ROC (macro):     0.9999
#   Training time:       291.4s
#
#   Per-class report:
#                             precision    recall  f1-score   support
#
#                     BENIGN       1.00      1.00      1.00    145907
#                       DDoS       1.00      1.00      1.00     25603
#                   DoS Hulk       1.00      1.00      1.00     19289
#           DoS Slowhttptest       0.99      1.00      0.99      1046
#              DoS Slowloris       1.00      0.99      0.99      1077
#                FTP-Patator       1.00      1.00      1.00      1186
#                SSH-Patator       1.00      1.00      1.00       644
#   Web Attack - Brute Force       0.75      0.70      0.72       294
# Web Attack - SQL Injection       1.00      0.75      0.86         4
#           Web Attack - XSS       0.42      0.51      0.46       130
#
#                   accuracy                           1.00    195180
#                  macro avg       0.92      0.89      0.90    195180
#               weighted avg       1.00      1.00      1.00    195180
# Saved: cm_xgboost.png

# %% [markdown]
# ## CELL 9 — XGBoost Learning Curve

# %%
# Plot validation loss across boosting rounds
results_dict = xgb_model.evals_result()
val_loss = results_dict['validation_0']['mlogloss']

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(val_loss, color=TEAL, linewidth=2, label='Validation Log Loss')
ax.set_xlabel('Boosting Round', fontsize=12)
ax.set_ylabel('Multiclass Log Loss', fontsize=12)
ax.set_title('XGBoost — Validation Loss Across Boosting Rounds', fontsize=13, fontweight='bold')
ax.legend(fontsize=11)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}xgb_learning_curve.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# # MODEL 3 — LSTM
#
# Long Short-Term Memory recurrent neural network for detecting temporally
# distributed attack patterns (Yin et al., 2017). Trained on PCA-reduced
# 16-component features reshaped as time sequences.
#
# > ⏱ **Expected training time:** 20–40 minutes on T4 GPU
# > ⚠️ LSTM requires GPU — ensure T4 runtime is selected (Runtime → Change runtime type)

# %% [markdown]
# ## CELL 10 — Prepare LSTM Inputs
#
# LSTM expects 3D input: (samples, timesteps, features).
# We treat each network flow's 16 PCA components as a sequence of 16 timesteps × 1 feature.

# %%
# ── Deferred TensorFlow import — only needed from here for the LSTM ────────
gc.collect()

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import to_categorical

print(f'TensorFlow: {tf.__version__}')
print(f'GPU available: {len(tf.config.list_physical_devices("GPU")) > 0}')
# Out:
# TensorFlow: 2.20.0
# GPU available: True

# %%
# Reshape PCA features for LSTM: (samples, timesteps=16, features=1)
X_train_lstm = X_train_pca_final.reshape(X_train_pca_final.shape[0], X_train_pca_final.shape[1], 1)
X_val_lstm   = X_val_pca.reshape(X_val_pca.shape[0], X_val_pca.shape[1], 1)
X_test_lstm  = X_test_pca.reshape(X_test_pca.shape[0],  X_test_pca.shape[1],  1)

# One-hot encode labels for categorical crossentropy
y_train_cat = to_categorical(y_train_final, num_classes=N_CLASSES)
y_val_cat   = to_categorical(y_val,         num_classes=N_CLASSES)
y_test_cat  = to_categorical(y_test,        num_classes=N_CLASSES)

print(f'LSTM input shapes:')
print(f'  X_train_lstm: {X_train_lstm.shape}  (samples, timesteps, features)')
print(f'  X_val_lstm:   {X_val_lstm.shape}')
print(f'  X_test_lstm:  {X_test_lstm.shape}')
print(f'  y_train_cat:  {y_train_cat.shape}   (one-hot encoded)')
print(f'  Timesteps: {X_train_lstm.shape[1]} | Features per step: {X_train_lstm.shape[2]}')
# Out:
# LSTM input shapes:
#   X_train_lstm: (5252634, 16, 1)  (samples, timesteps, features)
#   X_val_lstm:   (583626, 16, 1)
#   X_test_lstm:  (195180, 16, 1)
#   y_train_cat:  (5252634, 10)   (one-hot encoded)
#   Timesteps: 16 | Features per step: 1

# %% [markdown]
# ## CELL 11 — Build and Train LSTM

# %%
# ── Model architecture ─────────────────────────────────────────────────────
lstm_model = Sequential([
    LSTM(128, input_shape=(X_train_lstm.shape[1], 1),
         return_sequences=True, name='lstm_1'),
    BatchNormalization(name='bn_1'),
    Dropout(0.3, name='dropout_1'),

    LSTM(64, return_sequences=False, name='lstm_2'),
    BatchNormalization(name='bn_2'),
    Dropout(0.3, name='dropout_2'),

    Dense(64, activation='relu', name='dense_1'),
    Dropout(0.2, name='dropout_3'),

    Dense(N_CLASSES, activation='softmax', name='output')
], name='LSTM_CyberRisk')

lstm_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

lstm_model.summary()

# ── Callbacks ──────────────────────────────────────────────────────────────
callbacks = [
    EarlyStopping(
        monitor='val_loss', patience=5,
        restore_best_weights=True, verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss', factor=0.5,
        patience=3, min_lr=1e-6, verbose=1
    ),
    ModelCheckpoint(
        filepath=f'{MODEL_DIR}lstm_best.keras',
        monitor='val_loss', save_best_only=True, verbose=1
    )
]

# ── Training ───────────────────────────────────────────────────────────────
print('\nTraining LSTM...')
print('Early stopping enabled (patience=5 epochs)\n')
t0 = time.time()

history = lstm_model.fit(
    X_train_lstm, y_train_cat,
    validation_data=(X_val_lstm, y_val_cat),
    epochs=30,
    batch_size=1024,
    callbacks=callbacks,
    verbose=1
)

lstm_time = time.time() - t0
print(f'\n LSTM trained in {lstm_time:.1f}s ({lstm_time/60:.1f} min)')
lstm_model.save(f'{MODEL_DIR}lstm_model.keras')
print(' Model saved to Drive')
# Out:
# Model: "LSTM_CyberRisk"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 16, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_1 (BatchNormalization)       │ (None, 16, 128)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_2 (BatchNormalization)       │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 121,546 (474.79 KB)
#  Trainable params: 121,162 (473.29 KB)
#  Non-trainable params: 384 (1.50 KB)
# Training LSTM...
# Early stopping enabled (patience=5 epochs)
#
# Epoch 1/30
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8386 - loss: 0.3913
# Epoch 1: val_loss improved from None to 0.21567, saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 95s 17ms/step - accuracy: 0.8714 - loss: 0.2805 - val_accuracy: 0.8884 - val_loss: 0.2157 - learning_rate: 0.0010
# Epoch 2/30
# 5128/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8910 - loss: 0.2180
# Epoch 2: val_loss improved from 0.21567 to 0.20150, saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 92s 18ms/step - accuracy: 0.8940 - loss: 0.2133 - val_accuracy: 0.8934 - val_loss: 0.2015 - learning_rate: 0.0010
# Epoch 3/30
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9011 - loss: 0.2021
# Epoch 3: val_loss improved from 0.20150 to 0.18559, saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 86s 17ms/step - accuracy: 0.9026 - loss: 0.1998 - val_accuracy: 0.9092 - val_loss: 0.1856 - learning_rate: 0.0010
# Epoch 4/30
# 5128/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9066 - loss: 0.1917
# Epoch 4: val_loss improved from 0.18559 to 0.18337, saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 142s 17ms/step - accuracy: 0.9076 - loss: 0.1904 - val_accuracy: 0.9069 - val_loss: 0.1834 - learning_rate: 0.0010
# Epoch 5/30
# 5128/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9096 - loss: 0.1872
# Epoch 5: val_loss did not improve from 0.18337
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 86s 17ms/step - accuracy: 0.9103 - loss: 0.1855 - val_accuracy: 0.9025 - val_loss: 0.1867 - learning_rate: 0.0010
# Epoch 6/30
# 5127/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9114 - loss: 0.1840
# Epoch 6: val_loss improved from 0.18337 to 0.17108, saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 86s 17ms/step - accuracy: 0.9117 - loss: 0.1836 - val_accuracy: 0.9171 - val_loss: 0.1711 - learning_rate: 0.0010
# Epoch 7/30
# 5129/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9132 - loss: 0.1794
# Epoch 7: val_loss did not improve from 0.17108
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 86s 17ms/step - accuracy: 0.9133 - loss: 0.1794 - val_accuracy: 0.9145 - val_loss: 0.1718 - learning_rate: 0.0010
# Epoch 8/30
# 5128/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9141 - loss: 0.1783
# Epoch 8: val_loss improved from 0.17108 to 0.16742, saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/Thesis/models/lstm_best.keras
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 143s 17ms/step - accuracy: 0.9141 - loss: 0.1781 - val_accuracy: 0.9175 - val_loss: 0.1674 - learning_rate: 0.0010
# Epoch 9/30
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9146 - loss: 0.1757
# Epoch 9: val_loss did not improve from 0.16742
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 86s 17ms/step - accuracy: 0.9147 - loss: 0.1757 - val_accuracy: 0.8990 - val_loss: 0.1809 - learning_rate: 0.0010
# Epoch 10/30
# 5129/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9153 - loss: 0.1748
# Epoch 10: val_loss did not improve from 0.16742
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 86s 17ms/step - accuracy: 0.9155 - loss: 0.1743 - val_accuracy: 0.9163 - val_loss: 0.1701 - learning_rate: 0.0010
# Epoch 11/30
# 5129/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9157 - loss: 0.1734
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_loss did not improve from 0.16742
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 86s 17ms/step - accuracy: 0.9159 - loss: 0.1730 - val_accuracy: 0.9022 - val_loss: 0.1756 - learning_rate: 0.0010
# Epoch 12/30
# 5129/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9173 - loss: 0.1686
# Epoch 12: val_loss did not improve from 0.16742
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 88s 17ms/step - accuracy: 0.9174 - loss: 0.1681 - val_accuracy: 0.9029 - val_loss: 0.1734 - learning_rate: 5.0000e-04
# Epoch 13/30
# 5129/5130 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9175 - loss: 0.1677
# Epoch 13: val_loss did not improve from 0.16742
# 5130/5130 ━━━━━━━━━━━━━━━━━━━━ 86s 17ms/step - accuracy: 0.9175 - loss: 0.1675 - val_accuracy: 0.9046 - val_loss: 0.1688 - learning_rate: 5.0000e-04
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
#
#  LSTM trained in 1247.1s (20.8 min)
#  Model saved to Drive

# %% [markdown]
# ## CELL 12 — LSTM Training History Plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss
axes[0].plot(history.history['loss'],     color=TEAL,      linewidth=2, label='Training Loss')
axes[0].plot(history.history['val_loss'], color=DARK_TEAL, linewidth=2, linestyle='--', label='Validation Loss')
axes[0].set_title('LSTM — Loss per Epoch', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Categorical Crossentropy')
axes[0].legend()

# Accuracy
axes[1].plot(history.history['accuracy'],     color=TEAL,      linewidth=2, label='Training Accuracy')
axes[1].plot(history.history['val_accuracy'], color=DARK_TEAL, linewidth=2, linestyle='--', label='Validation Accuracy')
axes[1].set_title('LSTM — Accuracy per Epoch', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.suptitle('LSTM Training History — CyberRisk Framework', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{FIG_DIR}lstm_training_history.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## CELL 13 — Evaluate LSTM

# %%
# CELL 13 — Evaluate LSTM
from tensorflow import keras
import numpy as np

# Load LSTM if not in memory
if 'lstm_model' not in dir():
    lstm_model = keras.models.load_model(f'{MODEL_DIR}lstm_best.keras')
    lstm_time = 0
    print(' LSTM model loaded from Drive')

# Reshape for LSTM input — must match training shape exactly:
# (samples, 16 PCA components as timesteps, 1 feature per step)
X_test_lstm = X_test_pca.reshape((X_test_pca.shape[0], X_test_pca.shape[1], 1))

y_prob_lstm = lstm_model.predict(X_test_lstm, batch_size=2048, verbose=1)
y_pred_lstm = np.argmax(y_prob_lstm, axis=1)

lstm_results = evaluate_model('LSTM', y_test, y_pred_lstm, y_prob_lstm, lstm_time)
all_results.append(lstm_results)

plot_confusion_matrix('LSTM', y_test, y_pred_lstm, 'cm_lstm.png')
plot_pr_curves('LSTM', y_test, y_prob_lstm, 'pr_lstm.png')
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#
# =======================================================
#   LSTM — Evaluation Results
# =======================================================
#   Macro F1-score:      0.7010
#   Weighted F1-score:   0.9823
#   Macro Precision:     0.6575
#   Macro Recall:        0.9103
#   Mean FPR:            0.0027
#   AUC-ROC (macro):     0.9993
#   Training time:       1247.1s
#
#   Per-class report:
#                             precision    recall  f1-score   support
#
#                     BENIGN       1.00      0.98      0.99    145907
#                       DDoS       0.96      1.00      0.98     25603
#                   DoS Hulk       0.99      0.99      0.99     19289
#           DoS Slowhttptest       0.86      1.00      0.92      1046
#              DoS Slowloris       0.96      0.99      0.97      1077
#                FTP-Patator       0.86      1.00      0.92      1186
#                SSH-Patator       0.55      0.93      0.69       644
#   Web Attack - Brute Force       0.28      0.39      0.32       294
# Web Attack - SQL Injection       0.01      1.00      0.02         4
#           Web Attack - XSS       0.12      0.84      0.21       130
#
#                   accuracy                           0.98    195180
#                  macro avg       0.66      0.91      0.70    195180
#               weighted avg       0.99      0.98      0.98    195180
# Saved: cm_lstm.png

# %% [markdown]
# ---
# # MODEL 4 — ISOLATION FOREST
#
# Unsupervised anomaly detector for identifying unusual network behaviour
# without requiring labelled training data. Complements supervised models
# for zero-day and novel attack detection.
#
# > ⏱ **Expected training time:** 5–10 minutes
# > Note: Isolation Forest produces binary outputs (normal / anomaly) not multi-class labels.

# %% [markdown]
# ## CELL 14 — Train Isolation Forest

# %%
# Isolation Forest trains on BENIGN traffic only (unsupervised: learns what "normal" looks like)
# Then flags deviations as anomalies
benign_mask = y_train_sm == 0  # Class 0 = BENIGN
X_train_benign = X_train_sm[benign_mask]

print(f'Training Isolation Forest on BENIGN traffic only...')
print(f'Training samples (BENIGN): {X_train_benign.shape[0]:,}')

t0 = time.time()

iso_forest = IsolationForest(
    n_estimators=200,
    contamination=0.267,  # ~26.7% of full dataset is attack traffic
    max_samples='auto',
    random_state=42,
    n_jobs=-1,
    verbose=1
)

iso_forest.fit(X_train_benign)
iso_time = time.time() - t0

print(f'\n Isolation Forest trained in {iso_time:.1f}s')
joblib.dump(iso_forest, f'{MODEL_DIR}isolation_forest.pkl')
print(' Model saved to Drive')
# Out:
# Training Isolation Forest on BENIGN traffic only...
# Training samples (BENIGN): 583,626
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    5.6s finished
#  Isolation Forest trained in 6.8s
#  Model saved to Drive

# %% [markdown]
# ## CELL 15 — Evaluate Isolation Forest

# %%
# Isolation Forest: +1 = normal (BENIGN), -1 = anomaly (ATTACK)
iso_raw_pred = iso_forest.predict(X_test)
iso_scores   = iso_forest.decision_function(X_test)  # Anomaly score

# Convert to binary: 0 = BENIGN, 1 = ATTACK (any)
y_pred_iso_binary = np.where(iso_raw_pred == 1, 0, 1)  # 1→BENIGN(0), -1→ATTACK(1)
y_test_binary     = np.where(y_test == 0, 0, 1)         # True: 0=BENIGN, 1=any attack

from sklearn.metrics import classification_report, confusion_matrix

print('=== ISOLATION FOREST — Binary Evaluation (BENIGN vs ATTACK) ===')
print(classification_report(y_test_binary, y_pred_iso_binary,
                             target_names=['BENIGN', 'ATTACK (any)']))

# Binary F1
iso_f1  = f1_score(y_test_binary, y_pred_iso_binary, average='macro')
iso_fpr_val = confusion_matrix(y_test_binary, y_pred_iso_binary)
fp = iso_fpr_val[0, 1]
tn = iso_fpr_val[0, 0]
iso_fpr = fp / (fp + tn) if (fp + tn) > 0 else 0

iso_results = {
    'model': 'Isolation Forest',
    'macro_f1': iso_f1,
    'weighted_f1': f1_score(y_test_binary, y_pred_iso_binary, average='weighted'),
    'macro_precision': precision_score(y_test_binary, y_pred_iso_binary, average='macro', zero_division=0),
    'macro_recall': recall_score(y_test_binary, y_pred_iso_binary, average='macro', zero_division=0),
    'fpr': iso_fpr,
    'auc_roc': roc_auc_score(y_test_binary, -iso_scores),  # Negative: lower score = more anomalous
    'training_time_s': iso_time
}
all_results.append(iso_results)

print(f'Macro F1:   {iso_f1:.4f}')
print(f'FPR:        {iso_fpr:.4f}')
print(f'AUC-ROC:    {iso_results["auc_roc"]:.4f}')
print(f'Training time: {iso_time:.1f}s')

# Confusion matrix
cm_iso = confusion_matrix(y_test_binary, y_pred_iso_binary)
fig, ax = plt.subplots(figsize=(7, 5))
sns.heatmap(cm_iso, annot=True, fmt='d', cmap='YlOrRd',
            xticklabels=['BENIGN', 'ATTACK'], yticklabels=['BENIGN', 'ATTACK'], ax=ax)
ax.set_title('Isolation Forest — Confusion Matrix (Binary)', fontsize=13, fontweight='bold')
ax.set_ylabel('True'); ax.set_xlabel('Predicted')
plt.tight_layout()
plt.savefig(f'{FIG_DIR}cm_isolation_forest.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.5s finished
# === ISOLATION FOREST — Binary Evaluation (BENIGN vs ATTACK) ===
#               precision    recall  f1-score   support
#
#       BENIGN       0.90      0.73      0.81    145907
# ATTACK (any)       0.49      0.76      0.59     49273
#
#     accuracy                           0.74    195180
#    macro avg       0.69      0.74      0.70    195180
# weighted avg       0.80      0.74      0.75    195180
#
# Macro F1:   0.7003
# FPR:        0.2685
# AUC-ROC:    0.8547
# Training time: 6.8s

# %%
# CELL 15b — Isolation Forest Contamination Sweep
# Uses X_train_benign (from Cell 14) and X_test / y_test_binary (from Cell 15)
# No retraining of any other model needed — this only touches Isolation Forest.

contamination_values = [0.05, 0.10, 0.15, 0.20, 0.267, 0.30, 0.35]
sweep_results = []

for c in contamination_values:
    t0 = time.time()
    iso_c = IsolationForest(
        n_estimators=200,
        contamination=c,
        max_samples='auto',
        random_state=42,
        n_jobs=-1
    )
    iso_c.fit(X_train_benign)
    train_time = time.time() - t0

    raw_pred = iso_c.predict(X_test)
    pred_binary = np.where(raw_pred == 1, 0, 1)  # 1→BENIGN(0), -1→ATTACK(1)

    tn, fp, fn, tp = confusion_matrix(y_test_binary, pred_binary).ravel()
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0

    sweep_results.append({
        'contamination': c,
        'FPR': round(fpr, 4),
        'Recall': round(recall, 4),
        'Precision': round(precision, 4),
        'train_time_s': round(train_time, 2)
    })
    print(f"c={c}: FPR={fpr:.4f}, Recall={recall:.4f}, Precision={precision:.4f}, time={train_time:.1f}s")

sweep_df = pd.DataFrame(sweep_results)
print()
print(sweep_df)

# Save so it's not lost if the session disconnects
sweep_df.to_csv(f'{MODEL_DIR}iso_contamination_sweep.csv', index=False)
print(f"\nSaved to {MODEL_DIR}iso_contamination_sweep.csv")
# Out:
# c=0.05: FPR=0.0504, Recall=0.4234, Precision=0.7395, time=6.7s
# c=0.1: FPR=0.1013, Recall=0.6949, Precision=0.6985, time=7.6s
# c=0.15: FPR=0.1509, Recall=0.7409, Precision=0.6238, time=7.1s
# c=0.2: FPR=0.2007, Recall=0.7444, Precision=0.5561, time=6.6s
# c=0.267: FPR=0.2685, Recall=0.7578, Precision=0.4880, time=7.5s
# c=0.3: FPR=0.3012, Recall=0.7598, Precision=0.4600, time=6.9s
# c=0.35: FPR=0.3516, Recall=0.8246, Precision=0.4419, time=6.7s
#
#    contamination     FPR  Recall  Precision  train_time_s
# 0          0.050  0.0504  0.4234     0.7395          6.65
# 1          0.100  0.1013  0.6949     0.6985          7.59
# 2          0.150  0.1509  0.7409     0.6238          7.12
# 3          0.200  0.2007  0.7444     0.5561          6.63
# 4          0.267  0.2685  0.7578     0.4880          7.52
# 5          0.300  0.3012  0.7598     0.4600          6.91
# 6          0.350  0.3516  0.8246     0.4419          6.73
#
# Saved to /content/drive/MyDrive/Thesis/models/iso_contamination_sweep.csv

# %% [markdown]
# ## CELL 16 — Isolation Forest Anomaly Score Distribution

# %%
fig, ax = plt.subplots(figsize=(12, 5))

benign_scores = iso_scores[y_test == 0]
attack_scores = iso_scores[y_test != 0]

ax.hist(benign_scores, bins=100, alpha=0.6, color=TEAL,      label='BENIGN',       density=True)
ax.hist(attack_scores, bins=100, alpha=0.6, color=DARK_TEAL, label='ATTACK (any)', density=True)
ax.axvline(x=0, color='red', linestyle='--', linewidth=1.5, label='Decision boundary (0)')
ax.set_xlabel('Anomaly Score (higher = more normal)', fontsize=12)
ax.set_ylabel('Density', fontsize=12)
ax.set_title('Isolation Forest — Anomaly Score Distribution\nBENIGN vs ATTACK Traffic',
             fontsize=13, fontweight='bold')
ax.legend(fontsize=11)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}iso_anomaly_scores.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# # SHAP EXPLAINABILITY ANALYSIS
#
# SHAP (SHapley Additive exPlanations) provides feature-level attribution
# for individual model predictions, satisfying DORA Article 13 auditability
# requirements (Arrieta et al., 2020).

# %% [markdown]
# ## CELL 17 — SHAP for Random Forest

# %%
# CELL 17 — SHAP for Random Forest

print('Computing SHAP values for Random Forest...')
print('Using 200-record sample for speed\n')

# Load saved RF model from Drive
import joblib
rf = joblib.load(f'{MODEL_DIR}random_forest.pkl')
print(' RF model loaded from Drive')

# Reduced sample size — 200 is sufficient for publication-quality SHAP plots
shap_sample_idx = np.random.choice(X_test.shape[0], size=200, replace=False)
X_shap = X_test[shap_sample_idx]
y_shap = y_test[shap_sample_idx]

# Use interventional path_dependency for speed
rf_explainer = shap.TreeExplainer(rf, feature_perturbation='tree_path_dependent')
rf_shap_vals = rf_explainer.shap_values(X_shap, check_additivity=False)

print(f'SHAP values computed — shape per class: {rf_shap_vals[0].shape}')

# Handle multiclass SHAP output format
if isinstance(rf_shap_vals, list):
    shap_for_plot = rf_shap_vals[1]
    mean_shap = np.mean([np.abs(rf_shap_vals[i]).mean(axis=0) for i in range(N_CLASSES)], axis=0)
else:
    shap_for_plot = rf_shap_vals[:, :, 1] if rf_shap_vals.ndim == 3 else rf_shap_vals
    mean_shap = np.abs(rf_shap_vals).mean(axis=0) if rf_shap_vals.ndim == 2 else np.abs(rf_shap_vals).mean(axis=(0,2))

# Plot 1: DDoS class summary
fig, ax = plt.subplots(figsize=(10, 8))
shap.summary_plot(
    shap_for_plot, X_shap,
    feature_names=feature_names,
    max_display=20, show=False
)
plt.title('SHAP Summary — Random Forest (DDoS Class)', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{FIG_DIR}shap_rf_ddos.png', dpi=150, bbox_inches='tight')
plt.show()

# Plot 2: Global importance
shap_importance = pd.Series(mean_shap, index=feature_names).sort_values(ascending=True).tail(20)
fig, ax = plt.subplots(figsize=(10, 8))
shap_importance.plot(kind='barh', ax=ax, color=TEAL, edgecolor='white')
ax.set_title('SHAP Feature Importance — Random Forest\nMean |SHAP| across all 10 classes',
             fontsize=13, fontweight='bold')
ax.set_xlabel('Mean |SHAP Value|', fontsize=12)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}shap_rf_global.png', dpi=150, bbox_inches='tight')
plt.show()
print(' SHAP Random Forest plots saved')
# Out:
# Computing SHAP values for Random Forest...
# Using 200-record sample for speed
#
#  RF model loaded from Drive
# SHAP values computed — shape per class: (78, 10)
#  SHAP Random Forest plots saved

# %% [markdown]
# ## CELL 18 — SHAP for XGBoost

# %%
# CELL 18 — SHAP for XGBoost

print('Computing SHAP values for XGBoost...')

# Load XGBoost model from Drive
import xgboost as xgb
xgb_model = xgb.XGBClassifier()
xgb_model.load_model(f'{MODEL_DIR}xgboost_model.json')
print(' XGBoost model loaded from Drive')

xgb_explainer = shap.TreeExplainer(xgb_model)
xgb_shap_vals = xgb_explainer.shap_values(X_shap)

print(f'SHAP values computed — shape: {np.array(xgb_shap_vals).shape}')

# Handle multiclass SHAP output format
if isinstance(xgb_shap_vals, list):
    xgb_shap_for_plot = xgb_shap_vals[1]
    mean_shap_xgb = np.mean([np.abs(xgb_shap_vals[i]).mean(axis=0) for i in range(N_CLASSES)], axis=0)
else:
    xgb_shap_for_plot = xgb_shap_vals[:, :, 1] if xgb_shap_vals.ndim == 3 else xgb_shap_vals
    mean_shap_xgb = np.abs(xgb_shap_vals).mean(axis=0) if xgb_shap_vals.ndim == 2 else np.abs(xgb_shap_vals).mean(axis=(0, 2))

# Plot 1: DDoS class summary
fig, ax = plt.subplots(figsize=(10, 8))
shap.summary_plot(
    xgb_shap_for_plot, X_shap,
    feature_names=feature_names,
    max_display=20, show=False
)
plt.title('SHAP Summary — XGBoost (DDoS Class)\nFeature impact on DDoS prediction',
          fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{FIG_DIR}shap_xgb_ddos.png', dpi=150, bbox_inches='tight')
plt.show()

# Plot 2: Global RF vs XGBoost comparison
# Each model's values are divided by its own total so both are on the same scale
# (RF SHAP is in probability units, XGBoost SHAP is in log-odds units)
DARK_TEAL = '#088A87'
xgb_shap_imp = pd.Series(mean_shap_xgb, index=feature_names)
rf_shap_imp  = pd.Series(mean_shap,     index=feature_names)

top15 = shap_importance.index[-15:].tolist()
compare_df = pd.DataFrame({
    'Random Forest': (rf_shap_imp  / rf_shap_imp.sum())[top15],
    'XGBoost':       (xgb_shap_imp / xgb_shap_imp.sum())[top15]
})

fig, ax = plt.subplots(figsize=(12, 7))
compare_df.plot(kind='barh', ax=ax, color=[TEAL, DARK_TEAL], edgecolor='white')
ax.set_title('SHAP Feature Importance — Random Forest vs XGBoost\nShare of total mean |SHAP| (top 15 features, all classes)',
             fontsize=13, fontweight='bold')
ax.set_xlabel('Share of total mean |SHAP|', fontsize=12)
ax.legend(fontsize=11)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}shap_rf_vs_xgb.png', dpi=150, bbox_inches='tight')
plt.show()
print(' SHAP XGBoost plots saved')

# Print the values so the dissertation text can quote them
print((compare_df * 100).round(1).sort_values('XGBoost', ascending=False).to_string())
# Out:
# Computing SHAP values for XGBoost...
#  XGBoost model loaded from Drive
# SHAP values computed — shape: (200, 78, 10)
#  SHAP XGBoost plots saved
#                          Random Forest  XGBoost
# Destination Port                   5.5     11.5
# Init_Win_bytes_backward            6.0      9.9
# Init_Win_bytes_forward             2.5      7.5
# min_seg_size_forward               3.4      6.3
# Fwd Packet Length Max              2.8      3.9
# Flow IAT Mean                      2.4      3.0
# Flow IAT Max                       2.5      1.7
# Average Packet Size                2.4      1.1
# Packet Length Std                  2.3      0.9
# Packet Length Variance             3.0      0.8
# Bwd Header Length                  2.6      0.8
# Packet Length Mean                 2.4      0.7
# Subflow Bwd Bytes                  2.3      0.5
# Bwd Packet Length Max              3.7      0.4
# Avg Bwd Segment Size               3.4      0.3

# %% [markdown]
# ---
# # COMPARATIVE MODEL EVALUATION
#
# Cross-model performance comparison for dissertation Chapter 4.

# %% [markdown]
# ## CELL 19 — Comparative Metrics Table

# %%
# CELL 19 — Comparative Metrics Table

# Build comparison dataframe from all_results
comp_df = pd.DataFrame(all_results).set_index('model')

# Rename columns to match dissertation display names
comp_df.columns = ['Macro F1', 'Weighted F1', 'Macro Precision', 'Macro Recall',
                   'Mean FPR', 'AUC-ROC', 'Training Time (s)']

# Round for display
display_df = comp_df.round(4)

print('=' * 75)
print('  COMPARATIVE MODEL EVALUATION — All Four Architectures')
print('=' * 75)
print(display_df.to_string())

# Save to CSV
comp_df.to_csv(f'{MODEL_DIR}model_comparison.csv')
print('\n Comparison table saved to Drive')

# Highlight best per metric
print('\nBest model per metric:')
for col in ['Macro F1', 'Weighted F1', 'AUC-ROC']:
    if col in comp_df.columns:
        best = comp_df[col].idxmax()
        val  = comp_df[col].max()
        print(f'  {col}: {best} ({val:.4f})')
print(f'  Lowest FPR:  {comp_df["Mean FPR"].idxmin()} ({comp_df["Mean FPR"].min():.4f})')
print(f'  Fastest:     {comp_df["Training Time (s)"].idxmin()} ({comp_df["Training Time (s)"].min():.1f}s)')
# Out:
# ===========================================================================
#   COMPARATIVE MODEL EVALUATION — All Four Architectures
# ===========================================================================
#                   Macro F1  Weighted F1  Macro Precision  Macro Recall  Mean FPR  AUC-ROC  Training Time (s)
# model
# Random Forest       0.7792       0.9949           0.7482        0.8967    0.0008   0.9997           224.9303
# XGBoost             0.9024       0.9990           0.9151        0.8943    0.0001   0.9999           291.4404
# LSTM                0.7010       0.9823           0.6575        0.9103    0.0027   0.9993          1247.0994
# Isolation Forest    0.7003       0.7530           0.6937        0.7447    0.2685   0.8547             6.7861
#
#  Comparison table saved to Drive
#
# Best model per metric:
#   Macro F1: XGBoost (0.9024)
#   Weighted F1: XGBoost (0.9990)
#   AUC-ROC: XGBoost (0.9999)
#   Lowest FPR:  XGBoost (0.0001)
#   Fastest:     Isolation Forest (6.8s)

# %% [markdown]
# ## CELL 20 — Comparative Visualisation

# %%
metrics = ['Macro F1', 'Weighted F1', 'Macro Precision', 'Macro Recall', 'AUC-ROC']
models  = comp_df.index.tolist()
colors  = [TEAL, DARK_TEAL, '#05A8A8', '#037775']

fig, axes = plt.subplots(1, len(metrics), figsize=(20, 6))

for ax, metric in zip(axes, metrics):
    if metric in comp_df.columns:
        vals = comp_df[metric].values
        bars = ax.bar(models, vals, color=colors, edgecolor='white', width=0.6)
        ax.set_title(metric, fontsize=11, fontweight='bold')
        ax.set_ylim(0, 1.05)
        ax.set_xticklabels(models, rotation=30, ha='right', fontsize=9)
        for bar, v in zip(bars, vals):
            ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
                    f'{v:.3f}', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.suptitle('Comparative Model Evaluation — Cyber Risk Analytics Framework\nCICIDS2017 Dataset',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{FIG_DIR}model_comparison.png', dpi=150, bbox_inches='tight')
plt.show()
print(' Comparison chart saved')
# Out:
#  Comparison chart saved

# %% [markdown]
# ## CELL 21 — F1 Per Class Heatmap (RF vs XGBoost vs LSTM)

# %%
# CELL 21 — F1 Per Class Heatmap (RF vs XGBoost vs LSTM)
from sklearn.metrics import f1_score
from tensorflow import keras

# Load models and generate predictions if not in memory
if 'y_pred_rf' not in dir():
    import joblib
    rf = joblib.load(f'{MODEL_DIR}random_forest.pkl')
    y_pred_rf = rf.predict(X_test)
    print(' RF predictions generated')

if 'y_pred_xgb' not in dir():
    import xgboost as xgb
    xgb_model = xgb.XGBClassifier()
    xgb_model.load_model(f'{MODEL_DIR}xgboost_model.json')
    y_pred_xgb = xgb_model.predict(X_test)
    print(' XGBoost predictions generated')

if 'y_pred_lstm' not in dir():
    lstm_model = keras.models.load_model(f'{MODEL_DIR}lstm_best.keras')
    X_test_lstm = X_test_pca.reshape((X_test_pca.shape[0], X_test_pca.shape[1], 1))
    y_prob_lstm = lstm_model.predict(X_test_lstm, batch_size=2048, verbose=0)
    y_pred_lstm = np.argmax(y_prob_lstm, axis=1)
    print(' LSTM predictions generated')

# Build per-class F1 dataframe
f1_per_class = {}
for name, y_pred in [
    ('Random Forest', y_pred_rf),
    ('XGBoost',       y_pred_xgb),
    ('LSTM',          y_pred_lstm)
]:
    f1_per_class[name] = f1_score(y_test, y_pred, average=None, zero_division=0)

f1_df = pd.DataFrame(f1_per_class, index=CLASS_NAMES)

fig, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(
    f1_df, annot=True, fmt='.3f',
    cmap='YlGn', vmin=0, vmax=1,
    linewidths=0.5, ax=ax, cbar=True
)
ax.set_title('Per-Class F1-Score — Random Forest vs XGBoost vs LSTM\n(CICIDS2017 Test Set)',
             fontsize=13, fontweight='bold')
ax.set_xlabel('Model', fontsize=12)
ax.set_ylabel('Attack Category', fontsize=12)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}f1_per_class_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()
print(' Per-class F1 heatmap saved')
# Out:
#  Per-class F1 heatmap saved

# %% [markdown]
# ---
# # RISK TIER DECISION-SUPPORT FRAMEWORK
#
# Translates ML model outputs into governance-compatible risk tiers
# aligned with ISO 31000 and DORA Article 13 (O5 in the research objectives).

# %% [markdown]
# ## CELL 22 — Define Risk Tier Mapping

# %%
# Risk tier mapping: attack category → risk score (0–100) → tier
# Based on CVSS-style severity, DORA Article 13 threat impact classification,
# and banking operational risk taxonomy

RISK_SCORE_MAP = {
    'BENIGN':                   0,
    'Web Attack - SQL Injection': 95,  # Critical — direct data exfiltration risk
    'DDoS':                      90,  # Critical — service availability impact
    'Web Attack - Brute Force':  80,  # High     — credential compromise
    'Web Attack - XSS':          75,  # High     — client-side code injection
    'SSH-Patator':               70,  # High     — infrastructure credential attack
    'FTP-Patator':               65,  # High     — service credential attack
    'DoS Hulk':                  60,  # Medium   — volumetric DoS
    'DoS Slowhttptest':          55,  # Medium   — slow DoS variant
    'DoS Slowloris':             50,  # Medium   — slow DoS variant
}

TIER_CONFIG = {
    'Critical': {'range': (85, 100), 'color': '#D32F2F', 'response': 'Immediate escalation. Isolate affected systems. Invoke Incident Response Plan. Notify CISO and regulators per DORA Article 19.'},
    'High':     {'range': (65, 84),  'color': '#F57C00', 'response': 'Alert SOC within 15 minutes. Block source IP. Initiate forensic logging. Review affected accounts.'},
    'Medium':   {'range': (40, 64),  'color': '#FBC02D', 'response': 'Log and monitor. Escalate if pattern persists beyond 30 minutes. Review firewall rules.'},
    'Low':      {'range': (0, 39),   'color': '#388E3C', 'response': 'Record in risk register. No immediate action required. Review in next daily report.'},
}

def get_risk_tier(score):
    # Continuous boundaries — no gap between tiers, handles non-integer
    # adjusted_score values (base_score * confidence) without falling
    # through to a default.
    if score >= 85:
        return 'Critical'
    elif score >= 65:
        return 'High'
    elif score >= 40:
        return 'Medium'
    else:
        return 'Low'

def classify_event(predicted_label, confidence_score):
    """Map a model prediction to a risk tier decision."""
    base_score = RISK_SCORE_MAP.get(predicted_label, 0)
    # Adjust score by model confidence (high confidence → full score)
    adjusted_score = base_score * confidence_score
    tier = get_risk_tier(adjusted_score)
    return {
        'predicted_class':  predicted_label,
        'confidence':       round(confidence_score, 4),
        'base_risk_score':  base_score,
        'adjusted_score':   round(adjusted_score, 1),
        'risk_tier':        tier,
        'response':         TIER_CONFIG[tier]['response']
    }

print(' Risk tier framework defined')
print('\nRisk tier ranges:')
for tier, cfg in TIER_CONFIG.items():
    print(f'  {tier}: score {cfg["range"][0]}–{cfg["range"][1]}')
# Out:
#  Risk tier framework defined
#
# Risk tier ranges:
#   Critical: score 85–100
#   High: score 65–84
#   Medium: score 40–64
#   Low: score 0–39

# %% [markdown]
# ## CELL 23 — Apply Risk Framework to Test Set (Best Model)

# %%
# CELL 23 — Apply Risk Framework to Test Set (Best Model)

# Load XGBoost and generate predictions if not in memory
if 'y_prob_xgb' not in dir():
    import xgboost as xgb
    xgb_model = xgb.XGBClassifier()
    xgb_model.load_model(f'{MODEL_DIR}xgboost_model.json')
    y_pred_xgb = xgb_model.predict(X_test)
    y_prob_xgb = xgb_model.predict_proba(X_test)
    print('✅ XGBoost predictions generated')

# Apply using best performing supervised model (RF or XGBoost — check Cell 19)
# Defaulting to XGBoost here; change to y_pred_rf / y_prob_rf if RF was better

print('Applying Risk Tier Framework to test set predictions (XGBoost)...')

risk_records = []
for i in range(len(y_test)):
    pred_class = CLASS_NAMES[y_pred_xgb[i]]
    confidence = y_prob_xgb[i].max()
    record = classify_event(pred_class, confidence)
    record['true_class'] = CLASS_NAMES[y_test[i]]
    risk_records.append(record)

risk_df = pd.DataFrame(risk_records)

print(f'\n Risk classification complete for {len(risk_df):,} network flow events')
print('\nRisk tier distribution:')
tier_counts = risk_df['risk_tier'].value_counts()
for tier in ['Critical', 'High', 'Medium', 'Low']:
    count = tier_counts.get(tier, 0)
    pct = count / len(risk_df) * 100
    print(f'  {tier:10s}: {count:8,} events ({pct:.2f}%)')

# Save
risk_df.to_csv(f'{MODEL_DIR}risk_tier_classifications.csv', index=False)
print('\n Risk classifications saved to Drive')
# Out:
# Applying Risk Tier Framework to test set predictions (XGBoost)...
#
#  Risk classification complete for 195,180 network flow events
#
# Risk tier distribution:
#   Critical  :   25,603 events (13.12%)
#   High      :      832 events (0.43%)
#   Medium    :   22,835 events (11.70%)
#   Low       :  145,910 events (74.76%)
#
#  Risk classifications saved to Drive

# %% [markdown]
# ## CELL 24 — Risk Tier Visualisation

# %%
tier_order  = ['Critical', 'High', 'Medium', 'Low']
tier_colors = [TIER_CONFIG[t]['color'] for t in tier_order]
tier_vals   = [tier_counts.get(t, 0) for t in tier_order]

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Bar chart
bars = axes[0].bar(tier_order, tier_vals, color=tier_colors, edgecolor='white', width=0.6)
for bar, v in zip(bars, tier_vals):
    axes[0].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 500,
                f'{v:,}\n({v/len(risk_df)*100:.1f}%)',
                ha='center', va='bottom', fontsize=10, fontweight='bold')
axes[0].set_title('Risk Tier Distribution\n(XGBoost predictions, test set)', fontsize=13, fontweight='bold')
axes[0].set_ylabel('Number of Network Flow Events', fontsize=11)
axes[0].set_xlabel('Risk Tier', fontsize=11)

# Pie chart
axes[1].pie(
    tier_vals,
    labels=[f'{t}\n{v:,} ({v/len(risk_df)*100:.1f}%)' for t, v in zip(tier_order, tier_vals)],
    colors=tier_colors,
    startangle=90,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)
axes[1].set_title('Risk Tier Proportions\n(ISO 31000 aligned)', fontsize=13, fontweight='bold')

plt.suptitle('Risk Tier Decision-Support Framework — DORA Article 13 Aligned\nCICIDS2017 Test Set | XGBoost Model',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{FIG_DIR}risk_tier_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## CELL 25 — Sample Risk Decision Report (10 events)

# %%
# Sample 2 events from each tier for a governance-facing report
# (stratified: at least 1 correct + 1 incorrect classification per tier,
# so the sample actually shows model failure modes, not just successes)
sample_events = []
for tier in ['Critical', 'High', 'Medium', 'Low']:
    tier_df = risk_df[risk_df['risk_tier'] == tier]
    correct = tier_df[tier_df['predicted_class'] == tier_df['true_class']]
    incorrect = tier_df[tier_df['predicted_class'] != tier_df['true_class']]
    picks = []
    if len(correct) > 0:
        picks.append(correct.sample(1, random_state=42))
    if len(incorrect) > 0:
        picks.append(incorrect.sample(1, random_state=42))
    remaining = 2 - sum(len(p) for p in picks)
    if remaining > 0:
        picks.append(tier_df.sample(min(remaining, len(tier_df)), random_state=42))
    sample_events.append(pd.concat(picks))

sample_df = pd.concat(sample_events, ignore_index=True)

print('='*100)
print('  SAMPLE RISK DECISION REPORT — Data-Driven Cyber Risk Analytics Framework')
print('  Institution: Digital Banking Environment | Framework: DORA Article 13 / ISO 31000')
print('='*100)

for _, row in sample_df.iterrows():
    tier_color_label = {'Critical': '🔴', 'High': '🟠', 'Medium': '🟡', 'Low': '🟢'}
    print(f"\n{tier_color_label[row['risk_tier']]} RISK TIER: {row['risk_tier'].upper()} | Score: {row['adjusted_score']} / 100")
    print(f"   Predicted Attack: {row['predicted_class']}  (True: {row['true_class']})")
    print(f"   Model Confidence: {row['confidence']*100:.1f}%")
    print(f"   Recommended Response: {row['response']}")
    print(f"   {'─'*90}")

# Also save formatted sample
sample_df.to_csv(f'{MODEL_DIR}sample_risk_report.csv', index=False)
print('\n Sample risk report saved to Drive')
# Out:
# ====================================================================================================
#   SAMPLE RISK DECISION REPORT — Data-Driven Cyber Risk Analytics Framework
#   Institution: Digital Banking Environment | Framework: DORA Article 13 / ISO 31000
# ====================================================================================================
#
# 🔴 RISK TIER: CRITICAL | Score: 90.0 / 100
#    Predicted Attack: DDoS  (True: DDoS)
#    Model Confidence: 100.0%
#    Recommended Response: Immediate escalation. Isolate affected systems. Invoke Incident Response Plan. Notify CISO and regulators per DORA Article 19.
#    ──────────────────────────────────────────────────────────────────────────────────────────
#
# 🔴 RISK TIER: CRITICAL | Score: 90.0 / 100
#    Predicted Attack: DDoS  (True: DDoS)
#    Model Confidence: 100.0%
#    Recommended Response: Immediate escalation. Isolate affected systems. Invoke Incident Response Plan. Notify CISO and regulators per DORA Article 19.
#    ──────────────────────────────────────────────────────────────────────────────────────────
#
# 🟠 RISK TIER: HIGH | Score: 80.0 / 100
#    Predicted Attack: Web Attack - Brute Force  (True: Web Attack - Brute Force)
#    Model Confidence: 100.0%
#    Recommended Response: Alert SOC within 15 minutes. Block source IP. Initiate forensic logging. Review affected accounts.
#    ──────────────────────────────────────────────────────────────────────────────────────────
#
# 🟠 RISK TIER: HIGH | Score: 66.9000015258789 / 100
#    Predicted Attack: Web Attack - XSS  (True: Web Attack - Brute Force)
#    Model Confidence: 89.2%
#    Recommended Response: Alert SOC within 15 minutes. Block source IP. Initiate forensic logging. Review affected accounts.
#    ──────────────────────────────────────────────────────────────────────────────────────────
#
# 🟡 RISK TIER: MEDIUM | Score: 60.0 / 100
#    Predicted Attack: DoS Hulk  (True: DoS Hulk)
#    Model Confidence: 100.0%
#    Recommended Response: Log and monitor. Escalate if pattern persists beyond 30 minutes. Review firewall rules.
#    ──────────────────────────────────────────────────────────────────────────────────────────
#
# 🟡 RISK TIER: MEDIUM | Score: 49.400001525878906 / 100
#    Predicted Attack: DoS Slowloris  (True: DoS Slowhttptest)
#    Model Confidence: 98.8%
#    Recommended Response: Log and monitor. Escalate if pattern persists beyond 30 minutes. Review firewall rules.
#    ──────────────────────────────────────────────────────────────────────────────────────────
#
# 🟢 RISK TIER: LOW | Score: 0.0 / 100
#    Predicted Attack: BENIGN  (True: BENIGN)
#    Model Confidence: 100.0%
#    Recommended Response: Record in risk register. No immediate action required. Review in next daily report.
#    ──────────────────────────────────────────────────────────────────────────────────────────
#
# 🟢 RISK TIER: LOW | Score: 34.900001525878906 / 100
#    Predicted Attack: DoS Hulk  (True: BENIGN)
#    Model Confidence: 58.2%
#    Recommended Response: Record in risk register. No immediate action required. Review in next daily report.
#    ──────────────────────────────────────────────────────────────────────────────────────────
#
#  Sample risk report saved to Drive

# %% [markdown]
# ---
# ## CELL 26 — Phase 2 Final Summary Report

# %%
# CELL 26 — Phase 2 Final Summary Report

print('='*65)
print('  PHASE 2 COMPLETE — FINAL SUMMARY')
print('='*65)

print(f'''
MODELS TRAINED AND EVALUATED:
   Random Forest    (n_estimators=200, 78 features, SMOTE-balanced)
   XGBoost          (n_estimators=300, 78 features, SMOTE-balanced)
   LSTM             (2-layer, 16 PCA components, GPU-accelerated)
   Isolation Forest (unsupervised, contamination=0.267)

EVALUATION METRICS COMPUTED:
   Macro & Weighted F1-score
   Precision, Recall (macro)
   AUC-ROC (macro, OvR)
   False Positive Rate
   Per-class classification reports
   Confusion matrices (counts + normalised)
   Precision-Recall curves

EXPLAINABILITY:
   SHAP TreeExplainer — Random Forest (global + DDoS class)
   SHAP TreeExplainer — XGBoost (global + RF comparison)

RISK FRAMEWORK:
   4-tier risk classification (Critical/High/Medium/Low)
   ISO 31000 aligned response recommendations
   DORA Article 13 compliant audit trail
   {len(risk_df):,} network events classified
''')

print('COMPARATIVE RESULTS:')
if 'comp_df' in dir():
    print(comp_df[['Macro F1', 'AUC-ROC', 'Mean FPR']].round(4).to_string())
else:
    # Load from saved CSV if comp_df not in memory
    import os
    csv_path = f'{MODEL_DIR}model_comparison.csv'
    if os.path.exists(csv_path):
        comp_df = pd.read_csv(csv_path, index_col='model')
        print(comp_df[['Macro F1', 'AUC-ROC', 'Mean FPR']].round(4).to_string())
    else:
        print('  (Run Cell 19 to generate comparison table)')

print(f'''
FILES SAVED TO DRIVE ({MODEL_DIR}):
  random_forest.pkl             — Trained RF model
  xgboost_model.json            — Trained XGBoost model
  lstm_model.keras              — Trained LSTM model
  isolation_forest.pkl          — Trained Isolation Forest
  model_comparison.csv          — Metrics comparison table
  risk_tier_classifications.csv — Full test set risk decisions
  sample_risk_report.csv        — Sample governance report

FIGURES SAVED TO DRIVE ({FIG_DIR}):
  cm_*.png                     — Confusion matrices (4 models)
  pr_*.png                     — Precision-Recall curves
  shap_*.png                   — SHAP explainability plots
  model_comparison.png         — Cross-model metrics chart
  f1_per_class_heatmap.png     — Per-class F1 comparison
  risk_tier_distribution.png   — Risk tier output chart

NEXT: Phase 3 — Dissertation write-up (Chapter 4: Results & Chapter 5: Discussion)
''')
print('='*65)
# Out:
# =================================================================
#   PHASE 2 COMPLETE — FINAL SUMMARY
# =================================================================
#
# MODELS TRAINED AND EVALUATED:
#    Random Forest    (n_estimators=200, 78 features, SMOTE-balanced)
#    XGBoost          (n_estimators=300, 78 features, SMOTE-balanced)
#    LSTM             (2-layer, 16 PCA components, GPU-accelerated)
#    Isolation Forest (unsupervised, contamination=0.267)
#
# EVALUATION METRICS COMPUTED:
#    Macro & Weighted F1-score
#    Precision, Recall (macro)
#    AUC-ROC (macro, OvR)
#    False Positive Rate
#    Per-class classification reports
#    Confusion matrices (counts + normalised)
#    Precision-Recall curves
#
# EXPLAINABILITY:
#    SHAP TreeExplainer — Random Forest (global + DDoS class)
#    SHAP TreeExplainer — XGBoost (global + RF comparison)
#
# RISK FRAMEWORK:
#    4-tier risk classification (Critical/High/Medium/Low)
#    ISO 31000 aligned response recommendations
#    DORA Article 13 compliant audit trail
#    195,180 network events classified
#
# COMPARATIVE RESULTS:
#                   Macro F1  AUC-ROC  Mean FPR
# model
# Random Forest       0.7792   0.9997    0.0008
# XGBoost             0.9024   0.9999    0.0001
# LSTM                0.7010   0.9993    0.0027
# Isolation Forest    0.7003   0.8547    0.2685
#
# FILES SAVED TO DRIVE (/content/drive/MyDrive/Thesis/models/):
#   random_forest.pkl             — Trained RF model
#   xgboost_model.json            — Trained XGBoost model
#   lstm_model.keras              — Trained LSTM model
#   isolation_forest.pkl          — Trained Isolation Forest
#   model_comparison.csv          — Metrics comparison table
#   risk_tier_classifications.csv — Full test set risk decisions
#   sample_risk_report.csv        — Sample governance report
#
# FIGURES SAVED TO DRIVE (/content/drive/MyDrive/Thesis/figures/):
#   cm_*.png                     — Confusion matrices (4 models)
#   pr_*.png                     — Precision-Recall curves
#   shap_*.png                   — SHAP explainability plots
#   model_comparison.png         — Cross-model metrics chart
#   f1_per_class_heatmap.png     — Per-class F1 comparison
#   risk_tier_distribution.png   — Risk tier output chart
#
# NEXT: Phase 3 — Dissertation write-up (Chapter 4: Results & Chapter 5: Discussion)
#
# =================================================================

# %%
from google.colab import drive
drive.mount('/content/drive')

import os, joblib, pandas as pd, matplotlib.pyplot as plt

FIG_DIR = '/content/drive/MyDrive/Thesis/figures/'
MODEL_PATH = '/content/drive/MyDrive/Thesis/models/random_forest.pkl'
FEATURES_PATH = '/content/drive/MyDrive/Thesis/preprocessed/feature_names.csv'
TEAL = '#0ABAB5'

# sanity check before loading
assert os.path.exists(MODEL_PATH), f"Not found: {MODEL_PATH} — check My Drive/Thesis/models/ contents below"
print("Files in models/:", os.listdir('/content/drive/MyDrive/Thesis/models/'))

rf = joblib.load(MODEL_PATH)
feature_names = pd.read_csv(FEATURES_PATH)['0'].tolist()

importances = pd.Series(rf.feature_importances_, index=feature_names).sort_values(ascending=True)
top20 = importances.nlargest(20).sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(10, 8))
bars = ax.barh(top20.index, top20.values, color=TEAL, edgecolor='white')
ax.set_xlabel('Feature Importance (Gini Impurity Reduction)', fontsize=12)
ax.set_title('Random Forest — Top 20 Feature Importances', fontsize=13, fontweight='bold')
for bar, val in zip(bars, top20.values):
    ax.text(bar.get_width() + 0.0005, bar.get_y() + bar.get_height()/2, f'{val:.4f}', va='center', fontsize=8)
plt.tight_layout()
plt.savefig(f'{FIG_DIR}rf_feature_importance.png', dpi=150, bbox_inches='tight')
plt.show()
print(' Saved rf_feature_importance.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files in models/: ['random_forest.pkl', 'xgboost_model.json', 'lstm_best.keras', 'lstm_model.keras', 'isolation_forest.pkl', 'iso_contamination_sweep.csv', 'model_comparison.csv', 'sample_risk_report.csv', 'risk_tier_classifications.csv']
#  Saved rf_feature_importance.png
